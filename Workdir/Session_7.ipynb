# %% [markdown]
# # Session 7
# ---------------------------------------------------------------------------------------

# %% [markdown]
# ### Steps
#
# 1. Collect
# 2. Clean-up
# 3. Analyse and Process
# 4. Plot

# %%
import pandas as pd

# %%
#skip_rows =1 ; deltes or skips the first row
#index_col = [#] makes the # as the index, does label based indexing like loc

df = pd.read_csv('Pokemon.csv', names = [ '#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
                                           'Sp. Def', 'Sp. Atk', 'Speed', 'Generation', 'Legendary'], 
                                         skiprows = 1, index_col = ['#'])

# %%
df
# Out:
#                           Name    Type 1  Type 2  Total   HP  Attack  Defense  \
# #
# 1                    Bulbasaur     Grass  Poison    318   45      49       49
# 2                      Ivysaur     Grass  Poison    405   60      62       63
# 3                     Venusaur     Grass  Poison    525   80      82       83
# 3        VenusaurMega Venusaur     Grass  Poison    625   80     100      123
# 4                   Charmander      Fire     NaN    309   39      52       43
# 5                   Charmeleon      Fire     NaN    405   58      64       58
# 6                    Charizard      Fire  Flying    534   78      84       78
# 6    CharizardMega Charizard X      Fire  Dragon    634   78     130      111
# 6    CharizardMega Charizard Y      Fire  Flying    634   78     104       78
# 7                     Squirtle     Water     NaN    314   44      48       65
# 8                    Wartortle     Water     NaN    405   59      63       80
# ...

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# ...

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Def  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Atk  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
from hashlib import  sha256

# %%
#b => byte
sha256(b'hello').hexdigest()
# Out:
# '2cf24dba5fb0a30e26e83b2ac5b9e29e1b161e5c1fa7425e73043362938b9824'

# %%
sha256(b'hello ').hexdigest()
# Out:
# '5e3235a8346e5a4585f8c58562f5052b8fe26a3bb122e1e96c76784964dfc461'

# %%
type('hello')
# Out:
# str

# %%
type(r'hello')
# Out:
# str

# %%
type(b'hello')
# Out:
# bytes

# %%
#sha256(b'hello ').hexdigest() , b changes into bytes
sha256('hello ').hexdigest()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-f2c10b8f42d8> in <module>()
#       1 #sha256(b'hello ').hexdigest() , b changes into bytes
# ----> 2 sha256('hello ').hexdigest()
#
# TypeError: Unicode-objects must be encoded before hashing

# %%
'hello'.encode()
# Out:
# b'hello'

# %%
b'hello'.decode()
# Out:
# 'hello'

# %%
#python 3.6
somevalue = 'hello'
f'this is {somevalue}'
# Out:
# 'this is hello'
